# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ether = pd.read_csv("eth.csv")

# %%
ether
# Out:
#             date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  \
# 0     2015-07-30       9206    6911      4449897       643.886124
# 1     2015-07-31        424    6863      3994458       582.027976
# 2     2015-08-01        413    5293      3044344       575.164179
# 3     2015-08-02        432    5358      3112348       580.878686
# 4     2015-08-03        444    5280      3099953       587.112311
# ...          ...        ...     ...          ...              ...
# 2068  2021-03-28     574675    6493    282881171     43567.098568
# 2069  2021-03-29     577924    6511    296707624     45570.207956
# 2070  2021-03-30     576687    6518    299679974     45977.289659
# 2071  2021-03-31     607390    6452    308052478     47745.269374
# 2072  2021-04-01     652694    6516    306095620     46976.000614
#
#       CapMrktCurUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  FeeMedNtv  ...  \
# 0               NaN  1.213355e+11         NaN         NaN        NaN  ...
# ...

# %%
ether.plot(x="date", y="HashRate", figsize=(26,12))
plt.yscale("log")

# %%
ether.plot(x="date", y="HashRate", figsize=(26,12))

# %%
ether.plot(x="date", y="PriceUSD", figsize=(26,12))
plt.yscale("log")

# %%
ether.plot(x="date", y="PriceUSD", figsize=(26,12))
